# %% [markdown]
# # Spatially Compress data
#
# Go through data and reduce compresstion

# %% [markdown]
# ### Video resoultion
#
# Open in vlc media > top tool bar: window > media information > codec details
#
# - original resolution: 427x240
# - target resolution 1: 213x120
# - target resolution 2: 107x60

# %% [markdown]
# ## Scaling video res with ffmpeg
#
# ffmpeg -i input.mp4 -vf scale=$w:$h <encoding-parameters> output.mp4
#
# where, $w and $h denote the required width and height of the destination video. For example, you could use -vf scale=640:480 to resize your video to 480p.

# %%
# import subprocess

# subprocess.call(
#     f'ffmpeg -i input.avi -vf scale=213x120 -preset slow -crf 18 output240.avi',
#     shell=True
# )

# %%
import os
import subprocess

DATA_SOURCE = "data_right_left_up_down_1200"
DATA_TARGET = "data_120_right_left_up_down_1200"

if DATA_TARGET not in os.listdir():
    os.mkdir(DATA_TARGET)
    os.mkdir(DATA_TARGET + "/test")
    os.mkdir(DATA_TARGET + "/train")
    os.mkdir(DATA_TARGET + "/validation")
    status = subprocess.call(f'cp {DATA_SOURCE + "/indx_df.csv"} {DATA_TARGET + "/indx_df.csv"}', shell=True)

# %%
def conver_files_in_folder(source, destination, resolution):
    for file in os.listdir(source):
        subprocess.call(
            f'ffmpeg -i {source + "/" + file} -vf scale={resolution[0]}x{resolution[1]} -preset slow -crf 18 {destination + "/" + file}',
            shell=True
        )


conver_files_in_folder(DATA_SOURCE + "/test", DATA_TARGET + "/test", (213, 120))
conver_files_in_folder(DATA_SOURCE + "/train", DATA_TARGET + "/train", (213, 120))
conver_files_in_folder(DATA_SOURCE + "/validation", DATA_TARGET + "/validation", (213, 120))
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/29315.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:04.25, start: 0.000000, bitrate: 349 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 427x240 [SAR 1:1 DAR 427:240], 342 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/29315.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/29315.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x55d599b32380] Invalid pixel aspect ratio 427/426, limit is 255/255 reducing
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/29315.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 255:254 DAR 3621:2032], q=2-31, 200 kb/s, SAR 427:426 DAR 427:240, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   51 fps=0.0 q=2.0 Lsize=     110kB time=00:00:04.25 bitrate= 212.1kbits/s speed=39.8x
# video:103kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.721989%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/24047.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:02.83, start: 0.000000, bitrate: 407 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 293x240 [SAR 1:1 DAR 293:240], 400 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/24047.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/24047.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x564bf3aae480] Invalid pixel aspect ratio 293/426, limit is 255/255 reducing
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/24047.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 152:221 DAR 1349:1105], q=2-31, 200 kb/s, SAR 293:426 DAR 293:240, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   34 fps=0.0 q=4.9 Lsize=     123kB time=00:00:02.83 bitrate= 357.0kbits/s speed= 167x
# video:117kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.575085%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/117681.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:04.92, start: 0.000000, bitrate: 281 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 427x240 [SAR 1:1 DAR 427:240], 274 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/117681.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/117681.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x561fe7a60bc0] Invalid pixel aspect ratio 427/426, limit is 255/255 reducing
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/117681.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 255:254 DAR 3621:2032], q=2-31, 200 kb/s, SAR 427:426 DAR 427:240, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   59 fps=0.0 q=2.0 Lsize=      78kB time=00:00:04.91 bitrate= 130.0kbits/s speed= 182x
# video:71kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 10.037329%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/208036.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:04.17, start: 0.000000, bitrate: 465 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 436x240 [SAR 1:1 DAR 109:60], 461 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/208036.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/208036.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/208036.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 218:213 DAR 109:60], q=2-31, 200 kb/s, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   50 fps=0.0 q=6.9 Lsize=     186kB time=00:00:04.16 bitrate= 366.1kbits/s speed= 138x
# video:179kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.849757%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/92039.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:02.83, start: 0.000000, bitrate: 372 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 427x240 [SAR 1:1 DAR 427:240], 364 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/92039.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/92039.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x5654d51fee00] Invalid pixel aspect ratio 427/426, limit is 255/255 reducing
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/92039.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 255:254 DAR 3621:2032], q=2-31, 200 kb/s, SAR 427:426 DAR 427:240, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   34 fps=0.0 q=2.0 Lsize=      79kB time=00:00:02.83 bitrate= 227.8kbits/s speed= 174x
# video:72kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 9.024315%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/50807.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:03.17, start: 0.000000, bitrate: 380 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 427x240 [SAR 1:1 DAR 427:240], 373 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/50807.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/50807.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x55b63bb48f00] Invalid pixel aspect ratio 427/426, limit is 255/255 reducing
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/50807.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 255:254 DAR 3621:2032], q=2-31, 200 kb/s, SAR 427:426 DAR 427:240, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   38 fps=0.0 q=2.1 Lsize=     116kB time=00:00:03.16 bitrate= 301.4kbits/s speed= 168x
# video:110kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.019214%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/132405.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:05.08, start: 0.000000, bitrate: 318 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 428x240 [SAR 1:1 DAR 107:60], 311 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/132405.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/132405.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/132405.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 214:213 DAR 107:60], q=2-31, 200 kb/s, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   61 fps=0.0 q=1.8 Lsize=     134kB time=00:00:05.08 bitrate= 215.9kbits/s speed= 195x
# video:127kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.651541%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/93837.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:02.67, start: 0.000000, bitrate: 311 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 427x240 [SAR 1:1 DAR 427:240], 300 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/93837.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/93837.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x5562cc968800] Invalid pixel aspect ratio 427/426, limit is 255/255 reducing
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/93837.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 255:254 DAR 3621:2032], q=2-31, 200 kb/s, SAR 427:426 DAR 427:240, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   32 fps=0.0 q=2.0 Lsize=      50kB time=00:00:02.66 bitrate= 153.9kbits/s speed= 170x
# video:44kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 14.831229%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/125409.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:03.25, start: 0.000000, bitrate: 440 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 320x240 [SAR 1:1 DAR 4:3], 434 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/125409.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/125409.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/125409.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 160:213 DAR 4:3], q=2-31, 200 kb/s, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   39 fps=0.0 q=3.4 Lsize=     143kB time=00:00:03.25 bitrate= 361.2kbits/s speed= 161x
# video:137kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.858129%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/65643.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:04.25, start: 0.000000, bitrate: 387 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 427x240 [SAR 1:1 DAR 427:240], 381 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/65643.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/65643.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x560a30e14200] Invalid pixel aspect ratio 427/426, limit is 255/255 reducing
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/65643.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 255:254 DAR 3621:2032], q=2-31, 200 kb/s, SAR 427:426 DAR 427:240, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   51 fps=0.0 q=3.6 Lsize=     165kB time=00:00:04.25 bitrate= 317.8kbits/s speed= 175x
# video:158kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.384815%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/22467.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:03.08, start: 0.000000, bitrate: 338 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 427x240 [SAR 1:1 DAR 427:240], 329 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/22467.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/22467.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x55f8a7018700] Invalid pixel aspect ratio 427/426, limit is 255/255 reducing
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/22467.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 255:254 DAR 3621:2032], q=2-31, 200 kb/s, SAR 427:426 DAR 427:240, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   37 fps=0.0 q=1.6 Lsize=      66kB time=00:00:03.08 bitrate= 175.1kbits/s speed= 177x
# video:59kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 11.113672%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/190920.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:05.00, start: 0.000000, bitrate: 333 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 432x240 [SAR 1:1 DAR 9:5], 326 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/190920.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/190920.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/190920.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 72:71 DAR 9:5], q=2-31, 200 kb/s, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   60 fps=0.0 q=2.0 Lsize=     114kB time=00:00:05.00 bitrate= 186.0kbits/s speed= 188x
# video:106kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.709371%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/82438.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:05.17, start: 0.000000, bitrate: 301 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 360x240 [SAR 1:1 DAR 3:2], 294 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/82438.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/82438.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/82438.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 60:71 DAR 3:2], q=2-31, 200 kb/s, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
# ...
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:03.75, start: 0.000000, bitrate: 375 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 427x240 [SAR 1:1 DAR 427:240], 369 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/57840.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/57840.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x5623f5fca240] Invalid pixel aspect ratio 427/426, limit is 255/255 reducing
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/57840.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 255:254 DAR 3621:2032], q=2-31, 200 kb/s, SAR 427:426 DAR 427:240, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   45 fps=0.0 q=2.3 Lsize=     133kB time=00:00:03.75 bitrate= 290.1kbits/s speed= 162x
# video:126kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.387644%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/94396.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:03.33, start: 0.000000, bitrate: 257 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 427x240 [SAR 1:1 DAR 427:240], 247 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/94396.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/94396.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x5570a3efe100] Invalid pixel aspect ratio 427/426, limit is 255/255 reducing
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/94396.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 255:254 DAR 3621:2032], q=2-31, 200 kb/s, SAR 427:426 DAR 427:240, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   40 fps=0.0 q=2.0 Lsize=      51kB time=00:00:03.33 bitrate= 126.3kbits/s speed= 186x
# video:45kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 14.900120%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/33282.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:02.83, start: 0.000000, bitrate: 356 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 427x240 [SAR 1:1 DAR 427:240], 348 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/33282.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/33282.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x55acd5608e40] Invalid pixel aspect ratio 427/426, limit is 255/255 reducing
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/33282.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 255:254 DAR 3621:2032], q=2-31, 200 kb/s, SAR 427:426 DAR 427:240, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   34 fps=0.0 q=2.8 Lsize=     103kB time=00:00:02.83 bitrate= 298.6kbits/s speed= 159x
# video:97kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.738125%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from 'data_right_left_up_down_1200/test/15370.avi':
#   Metadata:
#     title           : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     encoder         : Lavf60.3.100
#   Duration: 00:00:03.83, start: 0.000000, bitrate: 349 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (FMP4 / 0x34504D46), yuv420p, 436x240 [SAR 1:1 DAR 109:60], 342 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Codec AVOption preset (Configuration preset) specified for output file #0 (data_120_right_left_up_down_1200/test/15370.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Codec AVOption crf (Select the quality for constant quality mode) specified for output file #0 (data_120_right_left_up_down_1200/test/15370.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'data_120_right_left_up_down_1200/test/15370.avi':
#   Metadata:
#     INAM            : (C) 2017 Twenty Billion Neurons GmbH, 20BN-Someting-Something-Dataset V2
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 213x120 [SAR 218:213 DAR 109:60], q=2-31, 200 kb/s, 12 fps, 12 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   46 fps=0.0 q=2.1 Lsize=     116kB time=00:00:03.83 bitrate= 248.8kbits/s speed= 172x
# video:110kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.209686%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       2     for file in os.listdir(source):
#       3         subprocess.call(
#       4             f'ffmpeg -i {source + "/" + file} -vf scale={resolution[0]}x{resolution[1]} -preset slow -crf 18 {destination + "/" + file}',
#       5             shell=True
#       6         )
# ----> 9 conver_files_in_folder(DATA_SOURCE + "/test", DATA_TARGET + "/test", (213, 120))
#      10 conver_files_in_folder(DATA_SOURCE + "/train", DATA_TARGET + "/train", (213, 120))
#      11 conver_files_in_folder(DATA_SOURCE + "/validation", DATA_TARGET + "/validation", (213, 120))
#
# Cell In[3], line 3, in conver_files_in_folder(source, destination, resolution)
#       1 def conver_files_in_folder(source, destination, resolution):
#       2     for file in os.listdir(source):
# ----> 3         subprocess.call(
#       4             f'ffmpeg -i {source + "/" + file} -vf scale={resolution[0]}x{resolution[1]} -preset slow -crf 18 {destination + "/" + file}',
#       5             shell=True
#       6         )
#
# File ~/.python/current/lib/python3.10/subprocess.py:347, in call(timeout, *popenargs, **kwargs)
#     345 with Popen(*popenargs, **kwargs) as p:
#     346     try:
# --> 347         return p.wait(timeout=timeout)
#     348     except:  # Including KeyboardInterrupt, wait handled that.
#     349         p.kill()
#
# File ~/.python/current/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File ~/.python/current/lib/python3.10/subprocess.py:1943, in Popen._wait(self, timeout)
#    1941 if self.returncode is not None:
#    1942     break  # Another thread waited.
# -> 1943 (pid, sts) = self._try_wait(0)
#    1944 # Check the pid and loop as waitpid has been known to
#    1945 # return 0 even without WNOHANG in odd situations.
#    1946 # http://bugs.python.org/issue14396.
#    1947 if pid == self.pid:
#
# File ~/.python/current/lib/python3.10/subprocess.py:1901, in Popen._try_wait(self, wait_flags)
#    1899 """All callers to this function MUST hold self._waitpid_lock."""
#    1900 try:
# -> 1901     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1902 except ChildProcessError:
#    1903     # This happens if SIGCLD is set to be ignored or waiting
#    1904     # for child processes has otherwise been disabled for our
#    1905     # process.  This child is dead, we can't get the status.
#    1906     pid = self.pid
#
# KeyboardInterrupt:
